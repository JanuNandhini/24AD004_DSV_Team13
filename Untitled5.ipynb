# %% [markdown]
# <a href="https://colab.research.google.com/github/JanuNandhini/24AD004_DSV_Team13/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("E.Janu")
# Out:
# E.Janu
